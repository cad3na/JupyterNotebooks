# %%
from scipy import *
a = zeros(1000)
a[:100]=1
b = fft(a)
plot(abs(b))

# %%
import control

# %%
G = control.tf([1,0],[1, 2, 5, 0])
control.bode(G);

# %%
control.nyquist(G);

# %%
control.matlab.bode(G);

# %%
w = linspace(0,2,100)

# %%
y,t = control.step(G, w)
plot(t,y)

# %%
ss = control.tf2ss(G)
ss
# Out:
# <control.statesp.StateSpace instance at 0x106390c68>

# %%
EU = control.tf([1,0],[1,0])
y,t = control.step(EU)
plot(t,y)

# %%
y, t = control.impulse(EU)
plot(t, y)
