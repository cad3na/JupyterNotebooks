# %%
from matplotlib.pyplot import figure, axes, autoscale
from matplotlib import rcParams
rcParams['savefig.pad_inches'] = 0
rcParams['font.size'] = 12
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['GMX']

# %%
from numpy import sin, linspace
x = linspace(0, 10, 100)
y = sin(x)

# %%
satelite = "Morelos 3"
sitio = "Iztapalapa"

# %%
fig = figure(figsize=(8.5,11), dpi=120)
ax = axes([0,0,0.85,1.1], frameon=False)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

ax.text(1,1,"MEXSAT Sistema Satelital Mexicano")
ax.text(1, 1.4, satelite)
ax.text(1, 1.8, "Sitio: " + sitio)

#ax.text(1,0.1,"Hola")

ax.axis([0,21.59,27.94,0])
#ax = ax.invert_yaxis()
autoscale(tight=True)

#ax.plot(x,y)
#fig.patch.set_visible(False)
#ax.patch.set_visible(False)

# %%
ax = fig.gca()

# %%
ax.invert_yaxis()

# %%
import matplotlib.font_manager
flist = matplotlib.font_manager.get_fontconfig_fonts()
names = [matplotlib.font_manager.FontProperties(fname=fname).get_name() for fname in flist]
for name in names:
    print(name)
# Out:
# Century Gothic
# Castellar
# Yu Gothic
# Magneto
# Microsoft PhagsPa
# Franklin Gothic Book
# Arial
# Papyrus
# Segoe UI Symbol
# Cambria
# Informal Roman
# Latin Modern Mono Prop
# Microsoft PhagsPa
# Latin Modern Sans
# Bodoni MT
# Microsoft JhengHei
# Bell MT
# Montserrat
# Book Antiqua
# Constantia
# Montserrat
# Latin Modern Mono
# Bodoni MT
# Leelawadee UI
# Bahnschrift
# Rockwell Condensed
# Segoe UI
# Latin Modern Roman Demi
# Montserrat
# Latin Modern Sans
# Sitka Small
# Wingdings
# Latin Modern Mono Light
# Rage Italic
# Rockwell
# Tahoma
# Latin Modern Mono Prop Light
# Microsoft JhengHei
# Corbel
# Microsoft Yi Baiti
# Lucida Fax
# Arial Rounded MT Bold
# Tw Cen MT Condensed
# Latin Modern Roman Slanted
# Latin Modern Mono
# Latin Modern Sans
# Chiller
# Franklin Gothic Demi
# Century Gothic
# Rockwell
# Microsoft YaHei
# Latin Modern Roman
# Latin Modern Roman Unslanted
# Perpetua
# MS Outlook
# Bodoni MT
# Latin Modern Mono Prop Light
# Latin Modern Sans
# ...
