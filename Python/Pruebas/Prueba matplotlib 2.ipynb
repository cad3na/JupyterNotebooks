# %%
eqs = []
eqs.append((r"$W^{3\beta}_{\delta_1 \rho_1 \sigma_2} = U^{3\beta}_{\delta_1 \rho_1} + \frac{1}{8 \pi 2} \int^{\alpha_2}_{\alpha_2} d \alpha^\prime_2 \left[\frac{ U^{2\beta}_{\delta_1 \rho_1} - \alpha^\prime_2U^{1\beta}_{\rho_1 \sigma_2} }{U^{0\beta}_{\rho_1 \sigma_2}}\right]$"))
eqs.append((r"$\frac{d\rho}{d t} + \rho \vec{v}\cdot\nabla\vec{v} = -\nabla p + \mu\nabla^2 \vec{v} + \rho \vec{g}$"))
eqs.append((r"$\int_{-\infty}^\infty e^{-x^2}dx=\sqrt{\pi}$"))
eqs.append((r"$E = mc^2 = \sqrt{{m_0}^2c^4 + p^2c^2}$"))
eqs.append((r"$F_G = G\frac{m_1m_2}{r^2}$"))


axes([0,0,2,2])

for i in range(24):
    index = random.randint(0,len(eqs))
    eq = eqs[index]
    size = random.uniform(12,32)
    x,y = random.uniform(0,1,2)
    alpha = random.uniform(0.25,.75)
    text(x, y, eq, ha='center', va='center', color="#11557c", alpha=alpha,
         transform=gca().transAxes, fontsize=size, clip_on=True)
xticks([]), yticks([])
# Out:
# (([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
ax = axes([0.025,0.025,0.95,0.95], polar=True)

N = 20
theta = arange(0.0, 2*np.pi, 2*np.pi/N)
radii = 10*random.rand(N)
width = pi/4*random.rand(N)
bars = bar(theta, radii, width=width, bottom=0.0)

for r,bar in zip(radii, bars):
    bar.set_facecolor(cm.jet(r/10.))
    bar.set_alpha(0.5)

ax.set_xticklabels([])
ax.set_yticklabels([])
# Out:
# []

# %%
ax = axes([0.025,0.025,0.95,0.95], polar=True)
#ax.set_xticklabels([])
#ax.set_yticklabels([])
