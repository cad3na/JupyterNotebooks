# %%
from pandas import DataFrame

# %%
df1 = DataFrame({"a":[1,2,3,4], "b": [5,6,7,8]})

# %%
df1
# Out:
#    a  b
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
df1[df1["a"]%2==0]
# Out:
#    a  b
# 1  2  6
# 3  4  8

# %%
from random import randint

# %%
temps_RF = [[randint(18,21) for i in range(13)] for i in range(5)]

# %%
temps_SR = [[randint(18,21) for i in range(13)] for i in range(5)]

# %%
from matplotlib.pyplot import figure, style
style.use("ggplot")

# %%
fig = figure(figsize=(15,5))
ax_RF, ax_SR = fig.subplots(2, sharex=True)
[ax_RF.plot(temps) for temps in temps_RF]
[ax_SR.plot(temps) for temps in temps_SR]
ax_RF.set_ylim(0,25)
ax_SR.set_ylim(0,25)
ax_SR.set_xlim(0,12)
fig.tight_layout()
fig.savefig("prueba.pdf")

# %%
fig.subplots?
# Out:
# Signature:
# fig.subplots(
#     nrows=1,
#     ncols=1,
#     sharex=False,
#     sharey=False,
#     squeeze=True,
#     subplot_kw=None,
#     gridspec_kw=None,
# )
# Docstring:
# Add a set of subplots to this figure.
#
# This utility wrapper makes it convenient to create common layouts of
# subplots in a single call.
#
# Parameters
# ----------
# nrows, ncols : int, optional, default: 1
#     Number of rows/columns of the subplot grid.
#
# sharex, sharey : bool or {'none', 'all', 'row', 'col'}, default: False
#     Controls sharing of properties among x (`sharex`) or y (`sharey`)
#     axes:
#
#         - True or 'all': x- or y-axis will be shared among all
#           subplots.
#         - False or 'none': each subplot x- or y-axis will be
#           independent.
#         - 'row': each subplot row will share an x- or y-axis.
#         - 'col': each subplot column will share an x- or y-axis.
#
#     When subplots have a shared x-axis along a column, only the x tick
# ...
