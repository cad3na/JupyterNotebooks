# %%
from matplotlib.pyplot import figure
from PIL import Image
from numpy import array, matrix, random
from cv2 import imread

# %%
im_arr = imread("c.png", 0)

# %%
fig = figure(figsize=(8.5,7.5))
ax = fig.gca()
ax.imshow(im_arr)

# %%
ran_arr = random.random(im_arr.shape)

# %%
ima_arr = (im_arr/256 + 0.9)

# %%
fig = figure(figsize=(8.5,7.5))
ax = fig.gca()
ax.imshow(ran_arr < ima_arr)
