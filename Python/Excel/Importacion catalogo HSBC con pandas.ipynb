# %%
from openpyxl import load_workbook
from pandas import DataFrame
wb = load_workbook(filename='catalogo-hsbc.xlsx', read_only=True)
ws = wb['Catálogo']

from openpyxl.utils.dataframe import dataframe_to_rows

for r in dataframe_to_rows(df, index=True, header=True):
    ws.append(r)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-e08be12b7e68> in <module>()
#       4 ws = wb['Catálogo']
#       5
# ----> 6 df = DataFrame(ws.values)
#
# AttributeError: 'ReadOnlyWorksheet' object has no attribute 'values'

# %%
from pandas import read_excel
df = read_excel('catalogo-hsbc.xlsx', sheetname='Catálogo')

# %%
ndf = df[6:]

# %%
ndf
# Out:
#     CATÁLOGO HSBC ATM'S 2013             Unnamed: 1 Unnamed: 2  \
# 6                        A01  TRABAJOS PRELIMINARES      10020
# 7                        A01  TRABAJOS PRELIMINARES      10030
# 8                        A01  TRABAJOS PRELIMINARES      10040
# 9                        A01  TRABAJOS PRELIMINARES      10050
# 10                       A01  TRABAJOS PRELIMINARES      10070
# 11                       A01  TRABAJOS PRELIMINARES      10080
# 12                       A01  TRABAJOS PRELIMINARES      10090
# 13                       A01  TRABAJOS PRELIMINARES      10110
# 14                       A01  TRABAJOS PRELIMINARES      10120
# 15                       A01  TRABAJOS PRELIMINARES      10130
# 16                       A01  TRABAJOS PRELIMINARES      10210
# 17                       A01  TRABAJOS PRELIMINARES      10220
# 18                       A01  TRABAJOS PRELIMINARES      10230
# 19                       A01  TRABAJOS PRELIMINARES      10240
# 20                       A01  TRABAJOS PRELIMINARES      10250
# 21                       A01  TRABAJOS PRELIMINARES      10340
# 22                       A01  TRABAJOS PRELIMINARES      10360
# 23                       A01  TRABAJOS PRELIMINARES      10370
# 24                       A01  TRABAJOS PRELIMINARES      10380
# 25                       A01  TRABAJOS PRELIMINARES      10410
# 26                       A01  TRABAJOS PRELIMINARES      10420
# 27                       A01  TRABAJOS PRELIMINARES      10440
# 28                       A01  TRABAJOS PRELIMINARES      10510
# 29                       A01  TRABAJOS PRELIMINARES      10530
# 30                       A01  TRABAJOS PRELIMINARES      10560
# 31                       A01  TRABAJOS PRELIMINARES      10580
# 32                       A01  TRABAJOS PRELIMINARES      10600
# 33                       A01  TRABAJOS PRELIMINARES      10620
# 34                       A01  TRABAJOS PRELIMINARES      10630
# 35                       A01  TRABAJOS PRELIMINARES      10710
# ..                       ...                    ...        ...
# 553                      A18              GENERALES     100330
# 554                      A18              GENERALES     100340
# 555                      A18              GENERALES     100350
# 556                      A18              GENERALES     100360
# 557                      A18              GENERALES     100365
# 558                      A18              GENERALES     100370
# 559                      A18              GENERALES     100380
# 560                      A18              GENERALES     100390
# 561                      A18              GENERALES     100400
# 562                      A18              GENERALES     100410
# 563                      A18              GENERALES     100420
# 564                      A18              GENERALES     100430
# 565                      A18              GENERALES     100440
# 566                      A18                    NaN     100450
# 567                      A18              GENERALES     100460
# 568                      A18              GENERALES     100470
# 569                      A18              GENERALES     100480
# 570                      A18              GENERALES     100490
# 571                      A18              GENERALES     100500
# 572                      A18              GENERALES     100510
# 573                      A18              GENERALES     100520
# 574                      A18              GENERALES     100530
# 575                      A18              GENERALES     100540
# 576                      A18              GENERALES     100550
# 577                      A18              GENERALES     100560
# 578                      A18              GENERALES     100570
# 579                      A19                 FLETES     110010
# 580                      A19                 FLETES     110020
# 581                      A19                 FLETES     110030
# 582                      A19                 FLETES     110040
#
#                                             Unnamed: 3 Unnamed: 4 Unnamed: 5  \
#
# 561  SUMINISTRO Y COLOCACIÓN DE PLACA DE 40 X 40 CM...        PZA    2350.06
# 562  SUMINISTRO Y COLOCACIÓN DE CHAMBRANAS (MOLDURA...        PZA     380.62
# 563  SUMINSITRO Y APLICACIÓN DE PINTURA EN SPRAY EN...        PZA    126.192
# 564  SUMINISTRO Y APLICACIÓN DE SILICON DOWN-CORNIN...         ML    16.3123
# 565  EMPLAYADO DE MOBILIARIO  (CAJEROS, ESCRITORIOS...        PZA    13.0498
# 566  CAMBIO DE LOSETAS ROTAS MONTAÑA LAGUNA POR LOS...        PZA      38.41
# 567  TAPA DE ALUMINIO EN DONDE ESTABA LA LECTORA DE...        PZA    106.682
# 568  RETIRO DE CALCOMANIAS EN PUERTAS Y CRISTALES D...        PZA    23.9247
# 569  RETIRO DE FACIAS IMAGEN ANTERIOR DE ACERO INOX...        PZA    111.826
# 570  LAMBRÍN DE TABLAROCA SIN ESTRUCTURA SOBRE MURO...         M2    102.528
# 571  AJUSTE DE VANO PARA EMPOTRAR  CAJERO NUEVO DE ...        PZA     551.22
# 572  LAMBRÍN EN MURO EXISTENTE UNA CARA DE TABLARRO...         M2     360.86
# 573  MURO DE DUROCK A UNA CARA DE 10 CMS. DE ANCHO ...         M2    285.356
# 574  SUMINISTRO Y COLOCACIÓN DE FALSO PLAFOND HYTON...         M2     187.58
# 575  CHAMBRANA A BASE DE MADERA DE PINO DE 19 MM PO...        PZA    311.021
# 576  RETIRO DE CONTACTOS ELECTRICOS Y/O VOZ Y DATOS...        PZA    21.8911
# 577  COLOCACIÓN DE CONTACTOS ELECTRICOS Y/O VOZ Y D...        PZA    28.3231
# 578  COLOCACIÓN DE CONTACTOS ELECTRICOS Y/O VOZ Y D...        JOR    815.614
# 579  FLETE DE UPS, COPETES, MARQUESINAS ADOSADAS, D...        FTE      283.5
# 580  FLETE CON MOBILIARIO DEL BANCO DENTRO DEL ÁREA...        FTE     770.59
# 581  FLETE DE ÁREA METROPOLITANA A A DIFERENTES PUN...         KM       13.6
# 582  TRASLADO DE LOCALIDAD DE ORIGEN A DIFERENTES P...         KM          3
#
#     Unnamed: 6 Unnamed: 7
# 6          NaN          0
# 7          NaN          0
# 8          NaN          0
# 9          NaN          0
# 10         NaN          0
# 11         NaN          0
# 12         NaN          0
# 13         NaN          0
# 14         NaN          0
# 15         NaN          0
# 16         NaN          0
# 17         NaN          0
# 18         NaN          0
# 19         NaN          0
# 20         NaN          0
# 21         NaN          0
# 22         NaN          0
# 23         NaN          0
# 24         NaN          0
# 25         NaN          0
# 26         NaN          0
# 27         NaN          0
# 28         NaN          0
# 29         NaN          0
# 30         NaN          0
# 31         NaN          0
# 32         NaN          0
# 33         NaN          0
# 34         NaN          0
# 35         NaN          0
# ..         ...        ...
# 553        NaN          0
# 554        NaN          0
# 555        NaN          0
# 556        NaN          0
# 557        NaN          0
# 558        NaN          0
# 559        NaN          0
# 560        NaN          0
# 561        NaN          0
# 562        NaN          0
# 563        NaN          0
# 564        NaN          0
# 565        NaN          0
# 566        NaN          0
# 567        NaN          0
# 568        NaN          0
# 569        NaN          0
# 570        NaN          0
# 571        NaN          0
# 572        NaN          0
# 573        NaN          0
# 574        NaN          0
# 575        NaN          0
# 576        NaN          0
# 577        NaN          0
# 578        NaN          0
# 579        NaN          0
# 580        NaN          0
# 581        NaN          0
# 582        NaN          0
#
# [577 rows x 8 columns]

# %%
nombres = df[5:6].get_values()

# %%
ndf.rename?
