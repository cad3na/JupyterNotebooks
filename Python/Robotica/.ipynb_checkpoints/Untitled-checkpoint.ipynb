# %%
# %matplotlib notebook

# %%
from matplotlib.pyplot import figure
from numpy import sin, linspace, sqrt

# %%
x = linspace(0, 10, 100)
y = sin(x)

# %%
f = figure(figsize=(8,8))
a = f.gca()
a.plot(x, y)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
x0 = 0
y0 = 0
A = 5
ω = 0.2
ϕ = 0

f1 = lambda x1: y0 + sqrt(100 - (x1 - x0)**2)
f2 = lambda x1: A*sin(ω*x1 + ϕ)

# %%
f = lambda x1: f1(x1) - f2(x1)

# %%
from numpy import sin, cos, linspace, roots
from scipy.optimize import newton

# %%
newton?

# %%
x1 = newton(f, 1)
y1 = f1(x1)
x1, y1
# Out:
# (8.7012034523856574, 4.9283930931077231)

# %%
def g1(x, x0, y0):
    l = 10
    y = y0 - sqrt(l**2 - (x - x0)**2)
    return y

def g2(x):
    A, ω, ϕ = 5, 0.2, 0
    y = A*sin(ω*x + ϕ)
    return y

# %%
g = lambda x, x0, y0: g1(x, x0, y0) - g2(x)

# %%
x1 = newton(g, 8, args=(0, 0))
y1 = g2(x1)
x1, y1
# Out:
# (8.7012034523856254, 4.9283930931077808)

# %%
xs = []
ys = []
xs.append(0)
ys.append(0)

for i in range(2):
    xs.append(newton(g, xs[-1] + 5, args=(xs[-1], ys[-1])))
    ys.append(g2(xs[-1]))
# Out:
# /Users/roberto/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: RuntimeWarning: invalid value encountered in sqrt
#   app.launch_new_instance()
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-86-3dd4a4effb32> in <module>()
#       5
#       6 for i in range(2):
# ----> 7     xs.append(newton(g, xs[-1] + 5, args=(xs[-1], ys[-1])))
#       8     ys.append(g2(xs[-1]))
#
# /Users/roberto/miniconda3/lib/python3.5/site-packages/scipy/optimize/zeros.py in newton(func, x0, fprime, args, tol, maxiter, fprime2)
#     182             q1 = func(*((p1,) + args))
#     183     msg = "Failed to converge after %d iterations, value is %s" % (maxiter, p)
# --> 184     raise RuntimeError(msg)
#     185
#     186
#
# RuntimeError: Failed to converge after 50 iterations, value is nan

# %%
xs, ys
# Out:
# ([0, 8.7012034523856254], [0, 4.9283930931077808])

# %%
x = linspace(0, 60, 100)

# %%
from matplotlib.pyplot import figure

# %%
f = figure(figsize=(6, 6))
a = f.gca()
a.plot(x, g1(x, 0, 0))
a.plot(x, g2(x))
a.plot(x, g1(x, xs[-1], ys[-1]))
a.set_xlim(0, 20)
a.set_ylim(-10, 10)
# Out:
# <img src="data:image/png;base64,..." width="600">
# /Users/roberto/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: RuntimeWarning: invalid value encountered in sqrt
#   app.launch_new_instance()
# (-10, 10)

# %%
def patron(x):
    A, ω, ϕ = 5, 0.2, 0
    return A*sin(ω*x+ϕ)
    
def h(x, x0, y0):
    d = 10
    return (patron(x) - y0)**2 + (x - x0)**2 - d**2

# %%
x1 = newton(h, 8, args=(0, 0))
y1 = g2(x1)
x1, y1
# Out:
# (8.7012034523856254, 4.9283930931077808)

# %%
xs = []
ys = []
xs.append(0)
ys.append(0)

for i in range(6):
    xs.append(newton(h, xs[-1] + 5, args=(xs[-1], ys[-1])))
    ys.append(g2(xs[-1]))

# %%
xs, ys
# Out:
# ([0,
#   8.7012034523856254,
#   16.737769157333481,
#   26.173857910711533,
#   33.722508811840427,
#   43.676823641916478,
#   51.072284671558826],
#  [0,
#   4.9283930931077808,
#   -1.0225405874213473,
#   -4.3331642504752246,
#   2.2256366744565428,
#   3.1804226524265014,
#   -3.5506364142465419])

# %%
x = linspace(0, 100, 500)
A, ω, ϕ = 5, 0.2, 0
y = patron(x)

# %%
f = figure(figsize=(8, 4))
a = f.gca()
a.plot(xs, ys)
a.plot(x, y)
a.set_xlim(0, 100)
a.set_ylim(-25, 25)
# Out:
# <img src="data:image/png;base64,..." width="800">
# (-25, 25)

# %%
def grafica_serpiente(phi = 0.0):
    def patron(x, phi):
        A, ω = 5, 0.2
        return A*sin(ω*x+phi)
    
    def h(x, x0, y0, phi):
        d = 10.5
        return (patron(x, phi) - y0)**2 + (x - x0)**2 - d**2
    
    xs = []
    ys = []
    xs.append(0)
    ys.append(patron(xs[-1], phi))

    for i in range(6):
        xs.append(newton(h, xs[-1] + 5, args=(xs[-1], ys[-1], phi)))
        ys.append(patron(xs[-1], phi))
        
    x = linspace(0, 100, 500)
    y = patron(x, phi)

    f = figure(figsize=(14, 7))
    a = f.gca()
    a.plot(xs, ys)
    a.plot(x, y)
    a.set_xlim(0, 60)
    a.set_ylim(-15, 15);

# %%
# %matplotlib inline

# %%
from ipywidgets import interactive

# %%
interactive(grafica_serpiente, phi=(0.0, 10))
