# %%
from numpy.random import normal
from numpy import linspace
pure = linspace(-1, 1, 20)
noise = normal(0, 1, 20)
signal = pure + noise

# %%
# %matplotlib inline
from matplotlib.pyplot import plot, style
style.use("ggplot")

# %%
plot(noise);

# %%
plot(signal);
