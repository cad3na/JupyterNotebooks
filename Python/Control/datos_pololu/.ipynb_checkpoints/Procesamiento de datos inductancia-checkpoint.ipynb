# %%
from pandas import read_csv

# %%
from matplotlib.pyplot import figure
# %matplotlib inline

# %%
df = read_csv("DATA000.CSV")
df.plot();

# %%
fig = figure(figsize=(16,8))
ax = fig.gca()
ax.plot(df["TRACK   1.0V*1"])
ax.plot([0, 4000], [106, 106], "--")
ax.plot([0, 4000], [90, 90], "--")
ax.plot([0, 4000], [63, 63], "--")

ax.plot([1077, 1077], [50, 170], "--")
ax.plot([1174, 1174], [50, 170], "--")
ax.plot([1094, 1094], [50, 170], "--")
ax.set_xlim(1074, 1274)
ax.set_ylim(60, 160);

# %%
(106-63)*.632+63
# Out:
# 90.176

# %%
T = 1094 - 1077
T
# Out:
# 17

# %% [markdown]
# $$
# 200 \implies 1.6ms
# $$
# $$
# 17 \implies x
# $$

# %%
t = 0.0016*17/200
t
# Out:
# 0.000136

# %%
R1 = 12.8
R2 = 220
R = R1 + R2

# %% [markdown]
# $$
# T = \frac{L}{R} \implies L = TR
# $$

# %%
L = t*R
L
# Out:
# 0.0316608

# %% [markdown]
# $$
# L = 31.6mH
# $$
