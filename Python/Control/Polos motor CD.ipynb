# %%
from control import tf, rlocus, step
from matplotlib.pyplot import style, figure
from numpy import linspace
style.use("ggplot")
# %matplotlib inline

# %%
Kb, Ka, K = (6/(120/60)), 1, ((0.93610*9.81/(100))/(0.42))
La, Ra = 0.0316, 12.8
Jm, Bm = 29.45e-09, 9.8734e-07
motor = tf([K*Ka], [La*Jm, Ra*Jm + La*Bm, Ra*Bm + Kb*K, 0])
motor, motor.pole()
# Out:
# (
#                  0.2186
#  ---------------------------------------
#  9.306e-10 s^3 + 4.082e-07 s^2 + 0.656 s,
#  array([-219.29463369+26548.18195319j, -219.29463369-26548.18195319j,
#            0.            +0.        j]))

# %%
(0.069*0.420)/9.81*100
# Out:
# 0.2954128440366972

# %%
rs, ks = rlocus(motor)

# %%
q, t = step(6*motor)

# %%
fig = figure(figsize=(15,8))
ax = fig.gca()
ax.plot(t, q)
