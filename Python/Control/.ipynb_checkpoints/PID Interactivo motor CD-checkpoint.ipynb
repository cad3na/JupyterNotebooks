# %%
# %matplotlib inline
from matplotlib.pyplot import figure, style
from control import tf, step_response, force
from numpy import linspace
style.use("ggplot")

# %%
from ipywidgets import interact

# %%
b, a = 50, 0.2
G = tf([b], [1,a,0])
t = linspace(0,2,1000)

# %%
t,y = step_response(G, t)

# %%
fig = figure(figsize=(15,8))
ax = fig.gca()
ax.plot(t,y)

# %%
Kp = 2
Ti = 0.15
Td = 0.0375
Ki = Ti
Kd = Td
G1 = tf([Kd,Kp,Ki],[1,0])
G1
# Out:
# 0.0375 s^2 + 2 s + 0.15
# -----------------------
#            s

# %%
1/50.2
# Out:
# 0.0199203187250996

# %%
t,y,x = step_response((G1*G).feedback(), t, return_x = True)
fig = figure(figsize=(15,8))
ax = fig.gca()
ax.plot(t,x[0])

# %%
def ejemplo(kp=1, ki=0.0, kd=0.0):
    t = linspace(0,2,100)
    con = tf([kd,kp,ki],[1,0])
    t,y,x = step_response((con*G).feedback(), t, return_x=True)
    fig = figure(figsize=(15,8))
    ax = fig.gca()
    ax.plot(t,y)
    #ax.plot(t,x[0])
    #ax.plot(t,x[1])
    #ax.plot(t,x[2])

# %%
interact(ejemplo, kp=(0.0, 10.0), ki=(0.0, 10.0), kd=(0.0, 10.0));
# Out:
# interactive(children=(FloatSlider(value=1.0, description='kp', max=10.0), FloatSlider(value=0.0, description='…

# %%
step_response?
