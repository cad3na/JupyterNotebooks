# %%
from control import tf, rlocus, bode, step_response
from matplotlib.pyplot import style, rcParams, figure
# %matplotlib widget
style.use("ggplot")
rcParams['figure.figsize'] = [18, 6]

# %%
G = tf([1], [1,1,1,3])

# %%
t,y = step_response(G)

# %%
fig = figure()
ax = fig.gca()
ax.plot(t,y)

# %%
r,k = rlocus(G)

# %%
Kp, Kd = 5,8
Con = tf([Kd, Kp], [1])
t,y = step_response((Con*G).feedback())
fig = figure()
ax = fig.gca()
ax.plot(t,y)
