# %%
# !scrapy runspider myspider.py
# Out:
# 2021-07-16 10:41:05 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: scrapybot)
# 2021-07-16 10:41:05 [scrapy.utils.log] INFO: Versions: lxml 4.6.3.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 21.2.0, Python 3.8.10 (default, May 19 2021, 11:01:55) - [Clang 10.0.0 ], pyOpenSSL 20.0.1 (OpenSSL 1.1.1k  25 Mar 2021), cryptography 3.4.7, Platform macOS-10.16-x86_64-i386-64bit
# 2021-07-16 10:41:05 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-07-16 10:41:05 [scrapy.crawler] INFO: Overridden settings:
# {'SPIDER_LOADER_WARN_ONLY': True}
# 2021-07-16 10:41:06 [scrapy.extensions.telnet] INFO: Telnet Password: 6a384c9984f77690
# 2021-07-16 10:41:06 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# ...
